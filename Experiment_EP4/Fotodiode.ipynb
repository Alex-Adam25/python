# %%
# %run ../odr_v3.1.ipynb
import matplotlib
matplotlib.rc('font', size=14)          # controls default text sizes

# %%
(I,Ua_10M)=txt2arr("10M")
(_,Ua_100K)=txt2arr("100K")

# %%
plt.figure(1)
plt.subplot(121)
plt.errorbar(x=I,y=Ua_10M/10e6*1e6,label="Messwerte",fmt='x',ms=16,c='b')
plt.xlabel("Relative Lichtintensität I [%]")
plt.ylabel("Photonenstrom $I_{Ph}$ [mA]")
draw("$R=10M\Omega$")
plt.subplot(122)
plt.errorbar(x=I,y=Ua_100K/100e3*1e6,label="Messwerte",fmt='x',ms=16,c='r')
plt.xlabel("Relative Lichtintensität I [%]")
plt.ylabel("Photonenstrom $I_{Ph}$ [mA]")
draw("$R=100K\Omega$",size=(14,6))
save("diode")
