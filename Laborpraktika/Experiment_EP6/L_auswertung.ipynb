# %%
# %run ../odr_v3.1.ipynb
# %run ../arr2table_v4.0.ipynb
import matplotlib
matplotlib.rc('font', size=14) 
import numpy as np

# %%
i_d,u_d,rel=txt2arr("L_1.1")

# %%
plt.figure(1)
plt.subplot(121)
plt.errorbar(x=rel,y=u_d*10**3,yerr=1,label="Messung $U_{Ph}$",fmt='.',c='b',capsize=6,ms=5)#Messwerte $\Delta U=1mV$
plt.xlabel("Relative Lichtintensität [%]")
plt.ylabel("Photospannung $U_{Ph}$ [mV]")
#plt.scale("log")
draw("")
plt.subplot(122)
plt.errorbar(x=rel,y=i_d,yerr=0.5,label="Messung $I_{Ph}$",fmt='.',c='b',capsize=6,ms=5)#Messwerte $\Delta I=0.5µA$

#plt.errorbar(x=rel,y=i_d,label="Messwerte",fmt='x',ms=16,c='r')
plt.xlabel("Relative Lichtintensität [%]")
plt.ylabel("Photostrom $I_{Ph}$ [µA]")

plt.suptitle('Photodiode',fontsize=20)
draw("",size=(14,6))
save("diode")

# %%
align='c'
head=["Lichtintensität [\%]","$U_{Ph}$ [mV]","$I_{Ph}$ [µA]"]
val=[rel,u_d*10**3,i_d]
err=[0,1,0.5] 
cap="Photodiode"
lab="PhDio"
nk=[0,0,1]
print(table(align,head,val,err,cap,lab,nk,longtable=False,copy=False))
# Out:
# \begin{table}[H]
# \centering
# \caption{Photodiode}
# \begin{tabular}{c|c|c}
# Lichtintensität [\%]	 &$U_{Ph}$ [mV]	 &$I_{Ph}$ [µA]	 \\\hline
# 100	&423$\pm$1	&67.8$\pm$0.5	\\
# 90	&418$\pm$1	&61.9$\pm$0.5	\\
# 80	&415$\pm$1	&56.6$\pm$0.5	\\
# 70	&409$\pm$1	&49.1$\pm$0.5	\\
# 60	&403$\pm$1	&41.8$\pm$0.5	\\
# 50	&396$\pm$1	&35.5$\pm$0.5	\\
# 40	&387$\pm$1	&28.4$\pm$0.5	\\
# 30	&377$\pm$1	&21.5$\pm$0.5	\\
# 20	&363$\pm$1	&14.6$\pm$0.5	\\
# 10	&342$\pm$1	&7.8$\pm$0.5	\\
# 0	&267$\pm$1	&0.5$\pm$0.5
# \label{Tab:PhDio}
# \end{tabular}
# \end{table}

# %%
np.array(i*2 for i in range(10))
# Out:
# array(<generator object <genexpr> at 0x0646BDB8>, dtype=object)

# %%
i_t,rel=txt2arr("L_1.2")

# %%
plt.errorbar(x=rel,y=i_t,yerr=3,label="Messung $I_{Ph}$",fmt='.',c='b',capsize=3,ms=5)#Messwerte $\Delta I=0.5µA$
plt.xlabel("Relative Lichtintensität [%]")
plt.ylabel("Photostrom $I_{Ph}$ [µA]")
#plt.scale("log")
draw("Phototransistor")
save("transistor")

# %%
align='c'
head=["Lichtintensität [\%]","$I_{Ph}$ [µA]"]
val=[rel,i_t]
err=[0,3] 
cap="Phototransistor"
lab="PhTran"
nk=0
print(table(align,head,val,err,cap,lab,nk,longtable=False,copy=False))
# Out:
# \begin{table}[H]
# \centering
# \caption{Phototransistor}
# \begin{tabular}{c|c}
# Lichtintensität [\%]	 &$I_{Ph}$ [µA]	 \\\hline
# 100	&192$\pm$3	\\
# 90	&167$\pm$3	\\
# 80	&151$\pm$3	\\
# 70	&130$\pm$3	\\
# 60	&120$\pm$3	\\
# 50	&100$\pm$3	\\
# 40	&80$\pm$3	\\
# 30	&59$\pm$3	\\
# 20	&38$\pm$3	\\
# 10	&20$\pm$3	\\
# 0	&2$\pm$3
# \label{Tab:PhTran}
# \end{tabular}
# \end{table}

# %%
farbe,u=txt2arr("L_1.3",strings=[0])
#np.flip()

# %%
x=np.arange(0,len(u))
plt.errorbar(x=x,y=u,label="Messwerte",fmt='x',ms=16,mew=4,color="b")
plt.ylabel("Durchlass-Spannung $U_{Ph}$ [V]")
plt.xlabel("LED Farbe")
x_ticks_labels = ['Violett','Blau','Grün','Grün','Orange','Rot']
ax = plt.gca()
ax.set_xticks(x)
ax.set_xticklabels(farbe, rotation='horizontal', fontsize=12)

draw()

# %%
col=["darkred","red","darkorange","gold","green","blue","grey"]
col=np.flip(col)
x=np.arange(0,len(u))
for i in range(len(u)):
    plt.scatter(x[i], u[i],marker="x", c = col[i],s=10, linewidth = 30,label="") 
    
ax = plt.gca()
ax.set_xticks(x)
plt.ylabel("Durchlass-Spannung $U_{Ph}$ [V]")
plt.xlabel("Farbe der LED")
ax.set_xticklabels(farbe, rotation='horizontal', fontsize=12)
draw("Spannung U=12V    Fehler: $\Delta U_{Ph}=0.01$V")
save("led")
# Out:
# No handles with labels found to put in legend.

# %%
align='c'
head=["LED Farbe","$U_{Ph}$ [V]"]
val=[farbe, u]
err=[0,0.01] 
cap="LED als Lichtquelle"
lab="LEDLicht"
nk=[0,2]
print(table(align,head,val,err,cap,lab,nk,longtable=False,copy=False))
# Out:
# \begin{table}[H]
# \centering
# \caption{LED als Lichtquelle}
# \begin{tabular}{c|c}
# LED Farbe	 &$U_{Ph}$ [V]	 \\\hline
# weiß	&2.91$\pm$0.01	\\
# blau	&2.88$\pm$0.01	\\
# grün	&2.08$\pm$0.01	\\
# gelb	&2.02$\pm$0.01	\\
# amber	&1.88$\pm$0.01	\\
# rot	&1.9$\pm$0.01	\\
# infrarot	&1.1$\pm$0.01
# \label{Tab:LEDLicht}
# \end{tabular}
# \end{table}

# %%
B=3500
R25=10e3
T25=298.15
def NTC_func(T):
    T=T+273.15
    return R25*np.exp(-B*(1/T25-1/T))

R0=1000
alpha=3.85e-3
def PTC_func(T):
    return R0*(1+alpha*T)

PTC_I_mess=np.array([9.19,8.92,12.52])*10**-3
PTC_U_mess=np.full(len(PTC_I_mess),10)
PTC_R_mess=PTC_U_mess/PTC_I_mess

NTC_I_mess=np.array([0.73,0.96,16*10**-3])*10**-3
NTC_U_mess=PTC_U_mess
NTC_R_mess=NTC_U_mess/NTC_I_mess

NTC_T_mess=PTC_T_mess=[20,30,-40]

#NTC_R_mess=np.array([339000.0,12780.0,12360.0])
#PTC_R_mess=np.array([812,1076,1122])

# %%
T=np.linspace(-50,30,10000)
NTC_R=NTC_func(T)
plt.plot(T,NTC_R*10**-3,label="theoretische Widerstandskurve",color="black")
# plt.xscale("log")
#plt.yscale("log")
plt.xlabel("Temperatur [°C]")
plt.ylabel("Widerstand [k$\Omega$]")

#plt.scatter(NTC_T_mess,NTC_R_mess*1e-3,marker="x",s=5, linewidth = 20,color="red",label="Messwerte")
plt.errorbar(NTC_T_mess,NTC_R_mess*10**-3,yerr=[15,15,65],fmt='.',ms=10,mew=2,capsize=10,color="blue",label="Messwerte ")

draw("NTC-Widerstand")
save("NTC")

# %%
T=np.linspace(-50,30,10000)
PTC_R=PTC_func(T)

plt.plot(T,PTC_R,label="theoretische Widerstandskurve",color="black")
# plt.xscale("log")
#plt.yscale("log")
plt.xlabel("Temperatur [°C]")
plt.ylabel("Widerstand [$\Omega$]")


plt.errorbar(PTC_T_mess,PTC_R_mess,yerr=10,fmt='.',ms=10,mew=2,capsize=10,color="blue",label="Messwerte $\Delta U=10\Omega$")

#plt.scatter(PTC_T_mess,PTC_R_mess,marker="x",s=5, linewidth = 20,color="red",label="Messwerte")
draw("PTC-Widerstand")
save("PTC")
