# %%
# %run ../odr_v3.1.ipynb
# %run ../arr2table_v3.3.ipynb

# %%
u_gs=np.array([2,3,4,1.5,1.7,1.9,2.1,2.2,2.5,2.8])
i_s=np.array([0.226e-3,9.98e-3,10e-3,0.2e-6,2.3e-6,88.8e-6,0.567e-3,0.882e-3,6.21e-3,9.96e-3])

# %%
import matplotlib

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 20
matplotlib.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
matplotlib.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels

# %%
def draw(title=""):
    k=1.5
    plt.gcf().set_size_inches(16/k, 9/k)
    plt.grid(b=True, which='major', linewidth=1)
    plt.grid(b=True, which='minor', linewidth=0.2)
    plt.minorticks_on()
    plt.title(title)
    plt.legend()
    

def save(save=""):
    plt.savefig(f"{save}.pdf",dpi=300,transparent=False)

# %%
plt.errorbar(x=u_gs,y=i_s,capsize=3,fmt='x',label="Messpunkte",ms=16)
plt.xlabel("Spannung $U_{GS}$ [V]")
plt.ylabel("Stromstärke $I_S$ [A]")
draw("Analyse des MOS-FET")
save("mosfet")

# %%
align='c'
head=["Spannung $U_{GS}$ [V]","Stromstärke $I_S$ [mA]"]
val=[u_gs,i_s*1e3]
err=[0,0] 
cap="MOS-FET"
lab="str"
nk=[1,2]
print(table(align,head,val,err,cap,lab,nk,longtable=False,copy=True))
# Out:
# \begin{table}[H]
# \centering
# \caption{MOS-FET}
# \begin{tabular}{c|c}
# Spannung $U_{GS}$ [V]	 &Stromstärke $I_S$ [mA]	 \\\hline
# 2.0	&0.23	\\
# 3.0	&9.98	\\
# 4.0	&10.00	\\
# 1.5	&0.00	\\
# 1.7	&0.00	\\
# 1.9	&0.09	\\
# 2.1	&0.57	\\
# 2.2	&0.88	\\
# 2.5	&6.21	\\
# 2.8	&9.96
# \label{Tab:str}
# \end{tabular}
# \end{table}

# %%
(ue,ua)=txt2arr("zen_span")

# %%
plt.errorbar(x=ue,y=ua,capsize=3,fmt='x',label="Messpunkte",ms=16)
plt.xlabel("Eingangsspannung $U_{e}$ [V]")
plt.ylabel("Ausgangsspannung $U_{a}$ [A]")
draw("Spannungsstabilisierung bzgl U")
plt.gcf().set_size_inches(7, 7)

save("ssU")

# %%
align='c'
head=["Eingangsspannung $U_{e}$ [V]","Ausgangsspannung $U_{a}$ [V]"]
val=[ue,ua]
err=[0,0] 
cap="Spannungsstabilisierung bzgl U"
lab="str"
nk=[1,3]
print(table(align,head,val,err,cap,lab,nk,longtable=False,copy=True))
# Out:
# \begin{table}[H]
# \centering
# \caption{Spannungsstabilisierung bzgl U}
# \begin{tabular}{c|c}
# Eingangsspannung $U_{e}$ [V]	 &Ausgangsspannung $U_{a}$ [V]	 \\\hline
# 1.0	&0.470	\\
# 2.0	&1.430	\\
# 3.0	&2.440	\\
# 4.0	&3.400	\\
# 5.0	&4.130	\\
# 6.0	&4.370	\\
# 7.0	&4.450	\\
# 8.0	&4.480	\\
# 9.0	&4.510	\\
# 10.0	&4.520	\\
# 11.0	&4.540	\\
# 12.0	&4.550	\\
# 13.0	&4.560	\\
# 14.0	&4.580	\\
# 15.0	&4.590	\\
# 16.0	&4.600	\\
# 17.0	&4.610	\\
# 18.0	&4.620	\\
# 19.0	&4.630	\\
# 20.0	&4.640
# \label{Tab:str}
# \end{tabular}
# \end{table}

# %%
(Ua,Ia)=txt2arr("zen_strom")
plt.errorbar(x=Ia,y=Ua,capsize=3,fmt='x',label="Messpunkte",ms=16)
plt.xlabel("Ausgangsspannung $U_{a}$ [V]")
plt.ylabel("Ausgangsstrom $I_{a}$ [mA]")
draw("Spannungsstabilisierung bzgl I")
save("ssI1")

# %%
(Ua,Ia)=txt2arr("zen_strom")
plt.errorbar(x=Ua,y=Ia,capsize=3,fmt='x',label="Messpunkte",ms=16)
plt.ylabel("Ausgangsspannung $U_{a}$ [V]")
plt.xlabel("Ausgangsstrom $I_{a}$ [mA]")
plt.ylim(4,5)

draw("Spannungsstabilisierung bzgl I")
plt.gcf().set_size_inches(7, 7)
save("ssI2")

# %%
align='c'
head=["Ausgangsspannung $U_{a}$ [V]","Ausgangsstrom $I_{a}$ [mA]"]
val=[Ua,Ia]
err=[0,0] 
cap="Spannungsstabilisierung bzgl I"
lab="str"
nk=[1,3]
print(table(align,head,val,err,cap,lab,nk,longtable=False,copy=True))
# Out:
# \begin{table}[H]
# \centering
# \caption{Spannungsstabilisierung bzgl I}
# \begin{tabular}{c|c}
# Ausgangsspannung $U_{a}$ [V]	 &Ausgangsstrom $I_{a}$ [mA]	 \\\hline
# 8.6	&4.460	\\
# 10.7	&4.460	\\
# 15.1	&4.450	\\
# 23.5	&4.440	\\
# 36.2	&4.420	\\
# 68.7	&4.400	\\
# 99.5	&4.390
# \label{Tab:str}
# \end{tabular}
# \end{table}
