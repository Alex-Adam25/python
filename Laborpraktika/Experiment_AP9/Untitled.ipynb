# %%
import numpy as np
import matplotlib.pyplot as plt
# %run ./odr.ipynb

x=np.arange(0,5,1)
y=[3]
out=zeichnen(x,y)
out.cov_beta=out.cov_beta*out.res_var
print(out.cov_beta)
print(np.sqrt(np.diag(out.cov_beta)))
print(np.prod(np.sqrt(np.diag(out.cov_beta))))
print(out.cov_beta[1][0])
print(out.cov_beta[0][1])
print(out.cov_beta[1][0]/np.prod(np.sqrt(np.diag(out.cov_beta))))
# Out:
# [[ 3.51044060e-32 -0.00000000e+00]
#  [-0.00000000e+00  5.00237834e-30]]
# [1.87361698e-16 2.23659973e-15]
# 4.1905312334461875e-31
# -0.0
# -0.0
# -0.0
