# %%
import numpy as np
def table(align,head,val,err,cap,lab,nk):
    #align: entweder 'l','c','r'
    #align="c"
    
    #head: np.array an titeln der spalten['a','b','c']
    #head=np.array(['a','b','c'])
    
    #val: np.array mit [] mit den Values zu den titeln[[1,2,3],[2,4,6],[3,6,9]]
    #val=np.array([[1,3,3],[9,4,6],[3,3,4]])
    
    #err: np.array mit [] zu den Values,[0] wenn keine error existieren
    #,wenn das array 1 wert besitz wird dieser für alle genommen ([[0.1,0.2,0.1],[0],[0.1]],dtype=object)
    #err=np.array([[0.1,0.2,0.1],[0],[0.1]],dtype=object)

    #cap: die caption
    #cap="jo"
    
    #lab: label mit tab: davor
    #lab="1a" => label: tab:1a
    
    #nk: np.array welches die Anzahl der Nachkommastellen beinhaltet für jeden Wert/Fehler 
    #oder skalar welches für alle werte die selbe Anzahl benutzt
    #nk=np.array([1,0,2])
    
    def rundennachkomma(a,n):
    #a ist array welches gerundet werden soll
    #n ist die anzahl der nachkommastellen
    #Erzeugt array mit den selben dimensionen wie a nur als string array(max 20 char)
        ar=np.empty_like(a,dtype='<U20')
        for i,v in enumerate(a):
            ar[i]="{:.{}f}".format(v,n)
        return ar
    
    if(len(nk)==1):
        nk=np.full(len(val),nk)
    
    valstr=np.empty_like(val,dtype='<U20')
    for i,array in enumerate(val): 
        valstr[i]=rundennachkomma(array,nk[i])
        
    for i,array in enumerate(err): 
        err[i]=rundennachkomma(array,nk[i])    
    
    size=len(val)
    fehler=np.zeros_like(val,dtype='<U20')
    val=np.transpose(val)
    valstr=np.transpose(valstr)
    a=(align+"|")*(size-1)+align
    tex="\\begin{longtable}{"+a+"} \n \n\\caption{"+cap+"}\\\ \n \n"
    
    for string in head:
        tex+=string+"\t &"
        
    tex=tex[:-1]+"\\\\"+"\\hline\\hline"+"\n"+"\\endfirsthead \n \n\\caption{Fortsetzung "+cap+"}\\\ \n \n"
    
    for string in head:
        tex+=string+"\t &"
    tex=tex[:-1]+"\\\\"+"\\hline\hline\n\endhead"+"\n"+"\hline\n\multicolumn{4}{r}{Weiter auf der n{\"a}chsten Seite}\\\n\endfoot\hline\n\multicolumn{4}{r}{Ende} \\\n\endlastfoot\n \n"
    
    
    for i,array in enumerate(err): 
        if(len(array)==len(val)):
            fehler[i]=array
        elif(len(array)==1):
            fehler[i]=np.full(len(val),array)
        else:
            print("Error größe stimmt nicht mit values überein")
            print(i)
            print(array)

    fehler=np.transpose(fehler)
    for i,array in enumerate(valstr):
        for j,v in enumerate(array):

            if(float(fehler[i,j])==0):
                tex=tex+v+"\t&"
            else:
                tex=tex+v+"$\\pm$"+str(fehler[i,j])+"\t&"
            
        tex=tex[:-1]+"\\\\ \n"
            
    tex=tex[:-4]+"\n"
        
    tex=tex+"\\label{tab:"+lab+"} \n \n\\end{longtable}"
    return tex

# %%
import numpy as np
U=np.array([496,494,493,493,493,492,491,491,495,497,497,497,497,497,497,496,496,496,496,496,496,497,497,497,496,497,497
           ,497,497,497,498,498,498,498,498,498,498,499,499,499,499,499,499,498,498,498,498,498,498,498,498,499,499,499
           ,499,499,499,499,499,499])

U_fehler=1
U_err=np.full(len(U),U_fehler)
#Zeit:
t2=np.array([3.59,2.68,5.74,4.17,2.38,3.57,3.53,7.72,3.12,2.09,1.49,2.03,2.03,1.2,1.28,2.12,
            1.90,7.20,7.62,2.77,1.84,2.12,2.08,1.89,3.59,3.89,4.14,5.39,41.69,3.92,2.93,1.83,6.64,1.63,2.29,9.37,3.05,7.76,6.92,4.03,7.44,
            3.23,4.21,2.11,9.00,6.51,2.86,3.24,2.26,8.73,7.32,3.44,4.38,8.75,5.60,4.03,3.78,2.35,4.75,3.02])
t1=np.array([22.16,22.05,5.24,32.58,24.69,32.95,33.94,14.92,34.78,83.15,27.44,54.09,50.33,7.29,25.89,36.08,
            9.33,28.60,27.48,46.90,17.89,26.28,26.36,21.60,9.70,14.43,14.80,22.48,13.70,28.81,16.22,21.24,28.76,17.86,59.12,23.59,11.14,13.41,10.20,25.01,3.30,
            8.08,30.05,9.08,25.23,39.53,16.67,16.89,29.22,26.89,31.92,27.61,11.26,16.86,3.95,4.58,5.23,26.39,55.28,14.13])


t_fehler=0.25
t_err=np.full(len(t1),t_fehler)
t1_err=t2_err=t_err

#Strecke; x ist gemessen durchs Mikroskop; s ist umgerechnet in den Realen wert
x=np.full(len(t1),2)

x_fehler=0.2
x_err=np.full(len(x),x_fehler)

#Position
z=1.875 #zoom

z_err=1.875*0.01
s=x/z*10**(-3)
s_err=np.sqrt((1/z*10**(-3)*x_err)**2+
              (x*10**(-3)*z_err/z**2)**2)

#Geschwindigkeit
v1=s/t1
v1_err=np.sqrt((s_err/t1)**2+(s*t1_err/t1**2)**2)
v2=s/t2
v2_err=np.sqrt((s_err/t2)**2+(s*t2_err/t2**2)**2)


eta=1.81*10**(-5)
d=6*10**(-3)
poel=875.3
pl=1.29
p=874
p_err=0
g=9.81

Q=(v1+v2)*np.sqrt(v1)/U*eta**(3/2)*18*np.pi*d/np.sqrt(2*p*g)


#Als BSP
#Q=np.array([1,2,2,2,3,3,3,3,3,4,6,6,6,6,6,8,9,9,9,9,10]);


Q_err=9*np.pi*d*eta**(3/2)/np.sqrt(g*p)*np.sqrt(((3*v1+v2)/(U*np.sqrt(2*v1))*v1_err)**2+
                                                (np.sqrt(2*v1)/U*v2_err)**2+
                                                (np.sqrt(2*v1)*(v1+v2)/U**2*U_err)**2)

#welches eta? 
r=np.sqrt(9*eta*v1/(2*p*g))

#r_err überprüfen
p=1013.25
b=8*10**(-5)
r_err=1/(2*np.sqrt(9*eta*v1/(2*p*g)))*9*eta/(2*p*g)*v1_err
r_err=r_err*10**(7)
Qk=Q/(1+b/(r*p))**(3/2)

Qk_err=np.sqrt((Q_err/(1+b/(r*p))**(3/2))**2+((3*b*Q)/(1+b/(r*p))**(5/2)*2*p*r**2)**2)


Q=Q*10**19
Qk=Qk*10**19
Qk_err=Qk_err*10**19
Q_err=Q_err*10**19
r=r*10**(7)

# %%
#Tabelle
head=np.array(['$U$ [V]','$t_1$ [s]','$t_2$ [s]','$Q$ [$10^{-19}\SI{}{\\ampere\s}$]','$r$ [$10^{-7}$m]','$Q_{kor}$ [$10^{-19}\SI{}{\\ampere\s}$]'])
val=np.array([U, t1, t2, Q,r,Qk])
nk=np.array([3])
err=np.array([U_err, t1_err, t2_err, Q_err,r_err,Qk_err], dtype=object)
#x anpassen
x=table(align="c",head=head,val=val,err=err,cap="Messwerte und $Q$ für $x=\SI{3.0\pm0.1}{\mm}$",lab="Mess",nk=nk)
print(x)
# Out:
# \begin{longtable}{c|c|c|c|c|c}
#
# \caption{Messwerte und $Q$ für $x=\SI{3.0\pm0.1}{\mm}$}\\
#
# $U$ [V]	 &$t_1$ [s]	 &$t_2$ [s]	 &$Q$ [$10^{-19}\SI{}{\ampere\s}$]	 &$r$ [$10^{-7}$m]	 &$Q_{kor}$ [$10^{-19}\SI{}{\ampere\s}$]	 \\\hline\hline
# \endfirsthead
#
# \caption{Fortsetzung Messwerte und $Q$ für $x=\SI{3.0\pm0.1}{\mm}$}\\
#
# $U$ [V]	 &$t_1$ [s]	 &$t_2$ [s]	 &$Q$ [$10^{-19}\SI{}{\ampere\s}$]	 &$r$ [$10^{-7}$m]	 &$Q_{kor}$ [$10^{-19}\SI{}{\ampere\s}$]	 \\\hline\hline
# \endhead
# \hline
# \multicolumn{4}{r}{Weiter auf der n{"a}chsten Seite}\
# \endfoot\hline
# \multicolumn{4}{r}{Ende} \
# \endlastfoot
#
# 496.000$\pm$1.000	&22.160$\pm$0.250	&3.590$\pm$0.250	&9.636$\pm$1.190	&6.762$\pm$0.318	&8.165$\pm$1.008	\\
# 494.000$\pm$1.000	&22.050$\pm$0.250	&2.680$\pm$0.250	&12.539$\pm$1.716	&6.779$\pm$0.318	&10.629$\pm$1.455	\\
# 493.000$\pm$1.000	&5.240$\pm$0.250	&5.740$\pm$0.250	&22.484$\pm$2.816	&13.906$\pm$0.718	&20.697$\pm$2.592	\\
# 493.000$\pm$1.000	&32.580$\pm$0.250	&4.170$\pm$0.250	&6.682$\pm$0.807	&5.577$\pm$0.261	&5.478$\pm$0.662	\\
# 493.000$\pm$1.000	&24.690$\pm$0.250	&2.380$\pm$0.250	&13.071$\pm$1.899	&6.406$\pm$0.300	&10.980$\pm$1.595	\\
# 492.000$\pm$1.000	&32.950$\pm$0.250	&3.570$\pm$0.250	&7.641$\pm$0.962	&5.546$\pm$0.260	&6.258$\pm$0.788	\\
# 491.000$\pm$1.000	&33.940$\pm$0.250	&3.530$\pm$0.250	&7.600$\pm$0.961	&5.464$\pm$0.256	&6.207$\pm$0.785	\\
