# %%
import netCDF4 as nc
fn="data.nc"
ds = nc.Dataset(fn)
print(ds)
print(ds.__dict__)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     title: CO Air Pollutant ANALYSIS at 2 levels
#     institution: Data produced by Meteo France
#     source: Data from ENSEMBLE model
#     history: Model ENSEMBLE ANALYSIS
#     ANALYSIS: Europe, 20201114-20201120+[1H_17H]
#     summary: ENSEMBLE model hourly ANALYSIS of CO concentration at 2 levels from 20201114-20201120+[1H_17H] on Europe
#     project: MACC-RAQ (http://macc-raq.gmes-atmosphere.eu)
#     dimensions(sizes): longitude(98), latitude(80), level(2), time(21)
#     variables(dimensions): float32 longitude(longitude), float32 latitude(latitude), float32 level(level), float32 time(time), float32 co_conc(time,level,latitude,longitude)
#     groups:
# {'title': 'CO Air Pollutant ANALYSIS at 2 levels', 'institution': 'Data produced by Meteo France', 'source': 'Data from ENSEMBLE model', 'history': 'Model ENSEMBLE ANALYSIS', 'ANALYSIS': 'Europe, 20201114-20201120+[1H_17H]', 'summary': 'ENSEMBLE model hourly ANALYSIS of CO concentration at 2 levels from 20201114-20201120+[1H_17H] on Europe', 'project': 'MACC-RAQ (http://macc-raq.gmes-atmosphere.eu)'}
# <ipython-input-5-6aa43b382244>:4: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(ds)
# <ipython-input-5-6aa43b382244>:5: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(ds.__dict__)

# %%
print(ds.__dict__['title'])
# Out:
# CO Air Pollutant ANALYSIS at 2 levels
# <ipython-input-8-eb4692d3c82e>:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(ds.__dict__['title'])

# %%
for var in ds.variables.values():
    print(var)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 longitude(longitude)
#     long_name: longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (98,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 latitude(latitude)
#     long_name: latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (80,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 level(level)
#     long_name: level
#     units: m
# unlimited dimensions:
# current shape = (2,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 time(time)
#     long_name: ANALYSIS time from 20201114
#     units: hours
# unlimited dimensions: time
# current shape = (21,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 co_conc(time, level, latitude, longitude)
#     _FillValue: -999.0
#     species: Carbon Monoxide
#     units: µg/m3
#     value: hourly values
#     standard_name: mass_concentration_of_carbon_monoxide_in_air
# unlimited dimensions: time
# current shape = (21, 2, 80, 98)
# filling on
# <ipython-input-6-f27cf27a8065>:2: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(var)

# %%
print(ds['level'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 level(level)
#     long_name: level
#     units: m
# unlimited dimensions:
# current shape = (2,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <ipython-input-7-3c1a8046ddad>:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(ds['level'])

# %%
for dim in ds.dimensions.values():
    print(dim)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'longitude', size = 98
# <class 'netCDF4._netCDF4.Dimension'>: name = 'latitude', size = 80
# <class 'netCDF4._netCDF4.Dimension'>: name = 'level', size = 2
# <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 21
# <ipython-input-9-5a8b7615d7a2>:2: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   print(dim)

# %%
ds['time'].shape[0]
# Out:
# 21

# %%
t=0
data=ds['co_conc'][t,0,:,:]
data.shape
# Out:
# (80, 98)

# %%
lon=ds['longitude'][:]
lat=ds['latitude'][:]

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
plt.imshow(data, cmap='hot')

# %%
for t in range(ds['time'].shape[0]):
    data=ds['co_conc'][t,0,:,:]
    plt.imshow(data, cmap='hot')
    plt.show()

# %%
print(data[0,0])
print(lat[0])
print(lon[0])
# Out:
# 148.88393
# 55.25
# 5.75
