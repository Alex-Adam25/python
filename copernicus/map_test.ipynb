# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14, 14))
m6 = plt.axes(projection=ccrs.PlateCarree())
# (x0, x1, y0, y1)
m6.set_extent([-30, 44, 70, -90], ccrs.PlateCarree())         
m6.coastlines()
plt.show()
