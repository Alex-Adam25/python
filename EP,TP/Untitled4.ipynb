# %%
import numpy as np
import matplotlib.pyplot as plt
# %run ../odr_v3.1.ipynb

# %%
t=np.linspace(0,2*np.pi,100)
vx=v=1
vy=0
w=1
X=np.array([[vx*t],[vy*t]])
plt.scatter(X[0],X[1])

# %%
x=X[0]*np.cos(w*t)
y=-X[0]*np.sin(w*t)

xges=v-v*t*w*np.sin(w*t)
yges=-v*t*w*np.cos(w*t)

# %%
plt.scatter(x,y)
for i in range(len(t)):
    plt.quiver(x[0][i],y[0][i],xges[i],yges[i],units='xy',alpha=0.75,width=0.02)
    
draw()
# Out:
# No handles with labels found to put in legend.

# %%
xges=v-v*t*w*np.sin(w*t)
yges=-v*t*w*np.cos(w*t)

# %%
plt.scatter(xges,yges)
