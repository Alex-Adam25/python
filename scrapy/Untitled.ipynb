# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import os

# %%
os.chdir(".\\impf")
os.listdir()
os.chdir(r"..")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-1421f1ac0c78> in <module>
# ----> 1 os.chdir(".\\impf")
#       2 os.listdir()
#       3 os.chdir(r"..")
#
# FileNotFoundError: [WinError 2] Das System kann die angegebene Datei nicht finden: '.\\impf'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '2021-01-13 12-23-41 (1).csv',
#  '2021-01-13 12-23-41.csv',
#  'alex',
#  'arr2table_v3.2.ipynb',
#  'arr2table_v3.3.ipynb',
#  'arr2table_v4.0.ipynb',
#  'conda',
#  'copernicus',
#  'covid',
#  'EP,TP',
#  'GUI',
#  'InfoStat',
#  'Klausurergebnisse',
#  'Laborpraktika',
#  'map',
#  'odr.ipynb',
#  'odr_v2.ipynb',
#  'odr_v3.1.ipynb',
#  'odr_v3.ipynb',
#  'README.md',
#  'run_all.txt',
#  'scrapy',
#  'wahl']

# %%
df.plot(x=list(df)[0], y=list(df)[1], style='o')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
ds=xr.Dataset.from_dataframe(df)
ds.plot(x=list(df)[0], y=list(df)[1], style='o')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7f4a97e4f379> in <module>
#       1 ds=xr.Dataset.from_dataframe(df)
# ----> 2 ds.plot(x=list(df)[0], y=list(df)[1], style='o')
#
# ~\anaconda3\lib\site-packages\xarray\plot\dataset_plot.py in __call__(self, *args, **kwargs)
#     157
#     158     def __call__(self, *args, **kwargs):
# --> 159         raise ValueError(
#     160             "Dataset.plot cannot be called directly. Use "
#     161             "an explicit plot method, e.g. ds.plot.scatter(...)"
#
# ValueError: Dataset.plot cannot be called directly. Use an explicit plot method, e.g. ds.plot.scatter(...)
